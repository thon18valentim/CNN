# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
from google.colab import drive
from tensorflow.keras import layers, models

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Set up the testing images and the training images. Each images pass through a resize and normalization function.

# %%
imagesTesting = []
labelsTesting = []
imagesTraining = []
labelsTraining = []
classLabels = ['barberry', 'bayberry', 'beach plum', 'bearberry', 'black berry', 'black cherry', 'blueberry', 'ceylon gooseberry', 'chokeberry', 'crowberry']

target_size = (224, 224)


def readTestingImages(i):
    os.chdir('/content/drive/MyDrive/Colab Notebooks/Images/Testing')

    for filename in os.listdir():
        if filename.endswith(".jpg") or filename.endswith(".png"):
            # Read Image
            image = cv2.imread(filename)
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Resize the image
            image_resized = cv2.resize(image_rgb, target_size)

            # Normalize the image
            image_normalized = image_resized / 255.0

            if i < 150:
              imagesTesting.append(image_normalized)

            # Extract label from filename
            labels = filename.rsplit("_", 1)
            label = labels[0].replace('_', ' ')

            # Get the index of the label in classLabels
            label_index = classLabels.index(label)

            if i < 150:
              labelsTesting.append(label_index)

            i += 1
            if i == 200:
              i = 0

i = 1
def readTrainingImages(i):
    os.chdir('/content/drive/MyDrive/Colab Notebooks/Images/Training')

    for filename in os.listdir():
        if filename.endswith(".jpg") or filename.endswith(".png"):
            # Read Image
            image = cv2.imread(filename)
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Resize the image
            image_resized = cv2.resize(image_rgb, target_size)

            # Normalize the image
            image_normalized = image_resized / 255.0

            if i < 50:
              imagesTraining.append(image_normalized)

            # Extract label from filename
            labels = filename.rsplit("_", 1)
            label = labels[0].replace('_', ' ')

            # Get the index of the label in classLabels
            label_index = classLabels.index(label)

            if i < 50:
              labelsTraining.append(label_index)

            i += 1
            if i == 200:
              i = 0

readTestingImages(1)
readTrainingImages(1)

# %%
# print(len(imagesTraining))
# print(len(imagesTesting))
# print(imagesTraining[0].shape)
# print(labelsTraining[0])
# plt.imshow(imagesTraining[0])
# plt.show()
# print(labelsTesting)
# device_name = tf.test.gpu_device_name()
# print(device_name)
# Out:
# (224, 224, 3)
# 5

# %% [markdown]
# # FIRST TRY MODEL

# %% [markdown]
# Set up the CNN architecture
#
# We start with a architecture of 7 layers. 2 are convolutional layers. 2 are max-pooling layers, a layer to flatten the previous output into a 1D vector, and 2 connected layers (dense layers).
#
# **model = models.Sequential()**: this creates a sequential model, which is a linear stack of layers
#
# **model.add(layers.Vonc2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))**: adds a 2D convolutional layer to the model with 32 filters. The number of filters determine the number of channels of the output feature maps. Each filter produces one feature map, and these feature maps collectively capture different aspects of the input data.
#
# **model.add(layers.MaxPooling2D((2, 2)))**: adds a max-pooling layer to the model with a pool size of 2x2. Max-pooling reduces the spatial dimensions of the feature maps.
#
# **model.add(layers.Flatten())**: this flattens the output of the previous layer into a 1D vector. This reshapes the multi-dimensional feature maps into a 1D vector that can be fed into the fully connected layer. Each element in the vector corresponds to a specific feature or activation in the feature map.
#
# **model.add(layers.Dense(64, activation='relu'))**: This adds a fully connected (dense) layer with 64 units and the ReLU activation function.
#
# **model.add(layers.Dense(10))**: This adds the final fully connected layer with 10 units. Since this is a classification problem with 10 classes, this layer will produce the output logits for each class.

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 186624)            0
#
#  dense (Dense)               (None, 64)                11944000
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 11,964,042
# Trainable params: 11,964,042
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training
#
# We compile the model using the following configuration:
#
# **optmizer=adam**: this sets the optimizer to adam
#
# **loss**: we set the loss function to sparse categorical crossentropy, indicating that the model does not have softmax activation applied, and the raw logits are used for calculating loss
#
# **metrics=accuracy**: indicates that the accuracy should be calculated during training
#
# To train the model, first we pass the images and labels list as numpy arrays and set the epoch value to 10.

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

history = model.fit(np.array(imagesTraining), np.array(labelsTraining), epochs=70, validation_data=(np.array(imagesTesting), np.array(labelsTesting)))
# Out:
# Epoch 1/70
# 16/16 [==============================] - 11s 266ms/step - loss: 4.5277 - accuracy: 0.1100 - val_loss: 2.2248 - val_accuracy: 0.1800
# Epoch 2/70
# 16/16 [==============================] - 2s 124ms/step - loss: 2.0753 - accuracy: 0.2560 - val_loss: 2.0224 - val_accuracy: 0.2820
# Epoch 3/70
# 16/16 [==============================] - 1s 94ms/step - loss: 1.4689 - accuracy: 0.5760 - val_loss: 2.0250 - val_accuracy: 0.2760
# Epoch 4/70
# 16/16 [==============================] - 2s 131ms/step - loss: 0.7484 - accuracy: 0.7860 - val_loss: 2.1050 - val_accuracy: 0.3307
# Epoch 5/70
# 16/16 [==============================] - 1s 89ms/step - loss: 0.2964 - accuracy: 0.9400 - val_loss: 2.4914 - val_accuracy: 0.3827
# Epoch 6/70
# 16/16 [==============================] - 1s 91ms/step - loss: 0.1102 - accuracy: 0.9780 - val_loss: 2.3557 - val_accuracy: 0.3720
# Epoch 7/70
# 16/16 [==============================] - 2s 126ms/step - loss: 0.0430 - accuracy: 0.9940 - val_loss: 2.5589 - val_accuracy: 0.3760
# Epoch 8/70
# 16/16 [==============================] - 1s 89ms/step - loss: 0.0222 - accuracy: 0.9960 - val_loss: 2.5944 - val_accuracy: 0.3833
# Epoch 9/70
# 16/16 [==============================] - 1s 89ms/step - loss: 0.0153 - accuracy: 0.9960 - val_loss: 2.8867 - val_accuracy: 0.3660
# Epoch 10/70
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0289 - accuracy: 0.9900 - val_loss: 2.6494 - val_accuracy: 0.3653
# Epoch 11/70
# 16/16 [==============================] - 2s 125ms/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 2.6128 - val_accuracy: 0.3733
# Epoch 12/70
# 16/16 [==============================] - 1s 92ms/step - loss: 0.0084 - accuracy: 0.9980 - val_loss: 2.7040 - val_accuracy: 0.3800
# Epoch 13/70
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.7355 - val_accuracy: 0.3727
# Epoch 14/70
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.6848 - val_accuracy: 0.3800
# Epoch 15/70
# 16/16 [==============================] - 1s 92ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.7977 - val_accuracy: 0.3860
# Epoch 16/70
# 16/16 [==============================] - 2s 125ms/step - loss: 7.8284e-04 - accuracy: 1.0000 - val_loss: 2.8368 - val_accuracy: 0.3880
# Epoch 17/70
# 16/16 [==============================] - 2s 124ms/step - loss: 6.7610e-04 - accuracy: 1.0000 - val_loss: 2.8159 - val_accuracy: 0.3913
# Epoch 18/70
# 16/16 [==============================] - 2s 126ms/step - loss: 5.7652e-04 - accuracy: 1.0000 - val_loss: 2.8355 - val_accuracy: 0.3887
# Epoch 19/70
# 16/16 [==============================] - 2s 129ms/step - loss: 4.8468e-04 - accuracy: 1.0000 - val_loss: 2.8922 - val_accuracy: 0.3873
# Epoch 20/70
# Epoch 58/70
# 16/16 [==============================] - 2s 125ms/step - loss: 6.1635e-05 - accuracy: 1.0000 - val_loss: 3.2876 - val_accuracy: 0.3933
# Epoch 59/70
# 16/16 [==============================] - 2s 131ms/step - loss: 5.9626e-05 - accuracy: 1.0000 - val_loss: 3.2994 - val_accuracy: 0.3947
# Epoch 60/70
# 16/16 [==============================] - 1s 90ms/step - loss: 5.7692e-05 - accuracy: 1.0000 - val_loss: 3.3088 - val_accuracy: 0.3973
# Epoch 61/70
# 16/16 [==============================] - 2s 125ms/step - loss: 5.5948e-05 - accuracy: 1.0000 - val_loss: 3.3117 - val_accuracy: 0.3947
# Epoch 62/70
# 16/16 [==============================] - 2s 124ms/step - loss: 5.4313e-05 - accuracy: 1.0000 - val_loss: 3.3152 - val_accuracy: 0.3947
# Epoch 63/70
# 16/16 [==============================] - 1s 89ms/step - loss: 5.2937e-05 - accuracy: 1.0000 - val_loss: 3.3295 - val_accuracy: 0.3960
# Epoch 64/70
# 16/16 [==============================] - 2s 125ms/step - loss: 5.1089e-05 - accuracy: 1.0000 - val_loss: 3.3332 - val_accuracy: 0.3953
# Epoch 65/70
# 16/16 [==============================] - 2s 125ms/step - loss: 4.9680e-05 - accuracy: 1.0000 - val_loss: 3.3395 - val_accuracy: 0.3953
# Epoch 66/70
# 16/16 [==============================] - 2s 131ms/step - loss: 4.8382e-05 - accuracy: 1.0000 - val_loss: 3.3429 - val_accuracy: 0.3953
# Epoch 67/70
# 16/16 [==============================] - 2s 129ms/step - loss: 4.6913e-05 - accuracy: 1.0000 - val_loss: 3.3514 - val_accuracy: 0.3947
# Epoch 68/70
# 16/16 [==============================] - 1s 90ms/step - loss: 4.5830e-05 - accuracy: 1.0000 - val_loss: 3.3598 - val_accuracy: 0.3947
# Epoch 69/70
# 16/16 [==============================] - 2s 126ms/step - loss: 4.4308e-05 - accuracy: 1.0000 - val_loss: 3.3599 - val_accuracy: 0.3953
# Epoch 70/70
# 16/16 [==============================] - 2s 125ms/step - loss: 4.3127e-05 - accuracy: 1.0000 - val_loss: 3.3692 - val_accuracy: 0.3953

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot accuracy graph
ax1.plot(history.history['accuracy'], label='accuracy')
ax1.plot(history.history['val_accuracy'], label='val_accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim([0.05, 1])
ax1.legend(loc='lower right')

# Plot loss graph
ax2.plot(history.history['loss'], label='loss')
ax2.plot(history.history['val_loss'], label='val_loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim([0.01, 10])
ax2.legend(loc='lower right')

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # TUNNING THE MODEL PART 1

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu')) # added another conv layer
model.add(layers.MaxPooling2D((2, 2))) # added another pooling layer
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_3 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 86528)             0
#
#  dense_2 (Dense)             (None, 64)                5537856
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 5,631,754
# Trainable params: 5,631,754
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

history = model.fit(np.array(imagesTraining), np.array(labelsTraining), epochs=70, validation_data=(np.array(imagesTesting), np.array(labelsTesting)))
# Out:
# Epoch 1/70
# 16/16 [==============================] - 8s 408ms/step - loss: 2.5151 - accuracy: 0.1260 - val_loss: 2.2279 - val_accuracy: 0.1480
# Epoch 2/70
# 16/16 [==============================] - 2s 134ms/step - loss: 2.1659 - accuracy: 0.2080 - val_loss: 2.1294 - val_accuracy: 0.2340
# Epoch 3/70
# 16/16 [==============================] - 2s 103ms/step - loss: 1.8942 - accuracy: 0.3560 - val_loss: 2.0063 - val_accuracy: 0.2740
# Epoch 4/70
# 16/16 [==============================] - 2s 103ms/step - loss: 1.5292 - accuracy: 0.4700 - val_loss: 2.1933 - val_accuracy: 0.3033
# Epoch 5/70
# 16/16 [==============================] - 2s 132ms/step - loss: 1.2446 - accuracy: 0.6140 - val_loss: 2.2933 - val_accuracy: 0.3480
# Epoch 6/70
# 16/16 [==============================] - 2s 131ms/step - loss: 0.9075 - accuracy: 0.7180 - val_loss: 2.2877 - val_accuracy: 0.3807
# Epoch 7/70
# 16/16 [==============================] - 2s 104ms/step - loss: 0.5200 - accuracy: 0.8720 - val_loss: 2.9361 - val_accuracy: 0.2880
# Epoch 8/70
# 16/16 [==============================] - 2s 111ms/step - loss: 0.4158 - accuracy: 0.8800 - val_loss: 2.6957 - val_accuracy: 0.3760
# Epoch 9/70
# 16/16 [==============================] - 2s 112ms/step - loss: 0.2479 - accuracy: 0.9300 - val_loss: 3.4157 - val_accuracy: 0.3147
# Epoch 10/70
# 16/16 [==============================] - 2s 132ms/step - loss: 0.2196 - accuracy: 0.9440 - val_loss: 3.7981 - val_accuracy: 0.3340
# Epoch 11/70
# 16/16 [==============================] - 2s 104ms/step - loss: 0.1704 - accuracy: 0.9600 - val_loss: 3.5130 - val_accuracy: 0.3787
# Epoch 12/70
# 16/16 [==============================] - 2s 104ms/step - loss: 0.0561 - accuracy: 0.9920 - val_loss: 3.9412 - val_accuracy: 0.3567
# Epoch 13/70
# 16/16 [==============================] - 2s 104ms/step - loss: 0.0199 - accuracy: 0.9980 - val_loss: 4.0059 - val_accuracy: 0.3847
# Epoch 14/70
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0166 - accuracy: 0.9980 - val_loss: 4.4419 - val_accuracy: 0.3967
# Epoch 15/70
# 16/16 [==============================] - 2s 104ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 4.4588 - val_accuracy: 0.4093
# Epoch 16/70
# 16/16 [==============================] - 2s 139ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 5.0863 - val_accuracy: 0.3933
# Epoch 17/70
# 16/16 [==============================] - 2s 131ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.9467 - val_accuracy: 0.3947
# Epoch 18/70
# 16/16 [==============================] - 2s 134ms/step - loss: 7.9573e-04 - accuracy: 1.0000 - val_loss: 4.9957 - val_accuracy: 0.3920
# Epoch 19/70
# 16/16 [==============================] - 2s 133ms/step - loss: 6.0778e-04 - accuracy: 1.0000 - val_loss: 5.1117 - val_accuracy: 0.3893
# Epoch 20/70
# 16/16 [==============================] - 2s 134ms/step - loss: 4.5763e-04 - accuracy: 1.0000 - val_loss: 5.1991 - val_accuracy: 0.3827
# Epoch 21/70
# 16/16 [==============================] - 2s 104ms/step - loss: 3.3388e-04 - accuracy: 1.0000 - val_loss: 5.3101 - val_accuracy: 0.3873
# Epoch 22/70
# 16/16 [==============================] - 2s 139ms/step - loss: 2.4958e-04 - accuracy: 1.0000 - val_loss: 5.3763 - val_accuracy: 0.3847
# Epoch 23/70
# Epoch 61/70
# 16/16 [==============================] - 2s 131ms/step - loss: 5.5296e-06 - accuracy: 1.0000 - val_loss: 6.3018 - val_accuracy: 0.3827
# Epoch 62/70
# 16/16 [==============================] - 2s 104ms/step - loss: 5.2781e-06 - accuracy: 1.0000 - val_loss: 6.3359 - val_accuracy: 0.3793
# Epoch 63/70
# 16/16 [==============================] - 2s 134ms/step - loss: 5.1131e-06 - accuracy: 1.0000 - val_loss: 6.3110 - val_accuracy: 0.3827
# Epoch 64/70
# 16/16 [==============================] - 2s 140ms/step - loss: 4.9746e-06 - accuracy: 1.0000 - val_loss: 6.3662 - val_accuracy: 0.3773
# Epoch 65/70
# 16/16 [==============================] - 2s 133ms/step - loss: 4.6837e-06 - accuracy: 1.0000 - val_loss: 6.3467 - val_accuracy: 0.3807
# Epoch 66/70
# 16/16 [==============================] - 2s 132ms/step - loss: 4.5483e-06 - accuracy: 1.0000 - val_loss: 6.3728 - val_accuracy: 0.3820
# Epoch 67/70
# 16/16 [==============================] - 2s 103ms/step - loss: 4.4181e-06 - accuracy: 1.0000 - val_loss: 6.3716 - val_accuracy: 0.3787
# Epoch 68/70
# 16/16 [==============================] - 2s 132ms/step - loss: 4.2429e-06 - accuracy: 1.0000 - val_loss: 6.3870 - val_accuracy: 0.3800
# Epoch 69/70
# 16/16 [==============================] - 2s 104ms/step - loss: 4.0853e-06 - accuracy: 1.0000 - val_loss: 6.4000 - val_accuracy: 0.3800
# Epoch 70/70
# 16/16 [==============================] - 2s 137ms/step - loss: 3.9325e-06 - accuracy: 1.0000 - val_loss: 6.4058 - val_accuracy: 0.3807

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot accuracy graph
ax1.plot(history.history['accuracy'], label='accuracy')
ax1.plot(history.history['val_accuracy'], label='val_accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim([0.5, 1])
ax1.legend(loc='lower right')

# Plot loss graph
ax2.plot(history.history['loss'], label='loss')
ax2.plot(history.history['val_loss'], label='val_loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim([0.5, 1])
ax2.legend(loc='lower right')

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # TUNNING THE MODEL PART 2

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), strides=(1,1), padding='same', activation='relu', input_shape=(224, 224, 3))) # added padding
model.add(layers.MaxPooling2D((2,2), padding='same'))
model.add(layers.Conv2D(64, (3, 3), strides=(2,2), padding='same', activation='relu'))
model.add(layers.MaxPooling2D((4,4), padding='same'))
model.add(layers.Conv2D(128, (3, 3), strides=(2,2), padding='same', activation='relu'))
model.add(layers.MaxPooling2D((4, 4),padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(500, activation='relu'))
model.add(layers.Dropout(0.4)) # added dropout
model.add(layers.Dense(250, activation='relu'))
model.add(layers.Dropout(0.3)) # added dropout
model.add(layers.Dense(10, activation='softmax')) # added activation

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 224, 224, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 32)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 500)               64500
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense_5 (Dense)             (None, 250)               125250
#
#  dropout_1 (Dropout)         (None, 250)               0
#
#  dense_6 (Dense)             (None, 10)                2510
#
# =================================================================
# Total params: 285,508
# Trainable params: 285,508
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

history = model.fit(np.array(imagesTraining), np.array(labelsTraining), epochs=70, validation_data=(np.array(imagesTesting), np.array(labelsTesting)))
# Out:
# Epoch 1/70
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 16/16 [==============================] - 9s 292ms/step - loss: 2.3078 - accuracy: 0.1080 - val_loss: 2.2820 - val_accuracy: 0.1873
# Epoch 2/70
# 16/16 [==============================] - 2s 122ms/step - loss: 2.2254 - accuracy: 0.1800 - val_loss: 2.1157 - val_accuracy: 0.1940
# Epoch 3/70
# 16/16 [==============================] - 1s 76ms/step - loss: 2.0981 - accuracy: 0.1740 - val_loss: 2.0269 - val_accuracy: 0.2033
# Epoch 4/70
# 16/16 [==============================] - 1s 77ms/step - loss: 1.9966 - accuracy: 0.2340 - val_loss: 1.9937 - val_accuracy: 0.2353
# Epoch 5/70
# 16/16 [==============================] - 2s 117ms/step - loss: 1.9654 - accuracy: 0.2320 - val_loss: 1.9751 - val_accuracy: 0.2440
# Epoch 6/70
# 16/16 [==============================] - 1s 78ms/step - loss: 1.9452 - accuracy: 0.2300 - val_loss: 1.9099 - val_accuracy: 0.2393
# Epoch 7/70
# 16/16 [==============================] - 1s 75ms/step - loss: 1.8071 - accuracy: 0.2980 - val_loss: 1.8519 - val_accuracy: 0.3013
# Epoch 8/70
# 16/16 [==============================] - 2s 117ms/step - loss: 1.7011 - accuracy: 0.3620 - val_loss: 1.7518 - val_accuracy: 0.3420
# Epoch 9/70
# 16/16 [==============================] - 1s 75ms/step - loss: 1.6578 - accuracy: 0.3560 - val_loss: 1.8032 - val_accuracy: 0.3380
# Epoch 10/70
# 16/16 [==============================] - 1s 82ms/step - loss: 1.6209 - accuracy: 0.3760 - val_loss: 1.7572 - val_accuracy: 0.3740
# Epoch 11/70
# 16/16 [==============================] - 1s 86ms/step - loss: 1.5451 - accuracy: 0.4080 - val_loss: 1.7371 - val_accuracy: 0.3707
# Epoch 12/70
# 16/16 [==============================] - 2s 121ms/step - loss: 1.4659 - accuracy: 0.4200 - val_loss: 1.7256 - val_accuracy: 0.3420
# Epoch 13/70
# 16/16 [==============================] - 1s 77ms/step - loss: 1.3419 - accuracy: 0.4740 - val_loss: 1.7632 - val_accuracy: 0.3653
# Epoch 14/70
# 16/16 [==============================] - 1s 75ms/step - loss: 1.2788 - accuracy: 0.5220 - val_loss: 1.6109 - val_accuracy: 0.4307
# Epoch 15/70
# 16/16 [==============================] - 1s 76ms/step - loss: 1.2232 - accuracy: 0.5160 - val_loss: 1.6835 - val_accuracy: 0.4067
# Epoch 16/70
# 16/16 [==============================] - 1s 76ms/step - loss: 1.1179 - accuracy: 0.5860 - val_loss: 1.7240 - val_accuracy: 0.4127
# Epoch 17/70
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0234 - accuracy: 0.6360 - val_loss: 1.8574 - val_accuracy: 0.4020
# Epoch 18/70
# 16/16 [==============================] - 1s 75ms/step - loss: 0.9958 - accuracy: 0.6300 - val_loss: 1.9309 - val_accuracy: 0.4000
# Epoch 19/70
# 16/16 [==============================] - 2s 116ms/step - loss: 0.8695 - accuracy: 0.6740 - val_loss: 1.7282 - val_accuracy: 0.4487
# Epoch 20/70
# 16/16 [==============================] - 1s 86ms/step - loss: 0.7481 - accuracy: 0.7380 - val_loss: 1.8582 - val_accuracy: 0.4167
# Epoch 21/70
# 16/16 [==============================] - 2s 120ms/step - loss: 0.7523 - accuracy: 0.7240 - val_loss: 1.9417 - val_accuracy: 0.4273
# Epoch 22/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.7367 - accuracy: 0.7600 - val_loss: 1.7180 - val_accuracy: 0.4767
# Epoch 23/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.5748 - accuracy: 0.7960 - val_loss: 2.1836 - val_accuracy: 0.4093
# Epoch 24/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.4956 - accuracy: 0.8280 - val_loss: 1.9779 - val_accuracy: 0.4647
# Epoch 25/70
# 16/16 [==============================] - 2s 116ms/step - loss: 0.3869 - accuracy: 0.8800 - val_loss: 1.8870 - val_accuracy: 0.4820
# Epoch 26/70
# 16/16 [==============================] - 1s 78ms/step - loss: 0.2852 - accuracy: 0.9300 - val_loss: 2.0097 - val_accuracy: 0.4833
# Epoch 27/70
# 16/16 [==============================] - 1s 75ms/step - loss: 0.2205 - accuracy: 0.9360 - val_loss: 2.1184 - val_accuracy: 0.4973
# Epoch 28/70
# 16/16 [==============================] - 1s 85ms/step - loss: 0.2821 - accuracy: 0.9140 - val_loss: 2.7648 - val_accuracy: 0.4313
# Epoch 29/70
# 16/16 [==============================] - 1s 84ms/step - loss: 0.2769 - accuracy: 0.9160 - val_loss: 2.1410 - val_accuracy: 0.4867
# Epoch 30/70
# 16/16 [==============================] - 2s 119ms/step - loss: 0.2374 - accuracy: 0.9340 - val_loss: 2.0484 - val_accuracy: 0.5033
# Epoch 31/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.1562 - accuracy: 0.9500 - val_loss: 2.5129 - val_accuracy: 0.4560
# Epoch 32/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.1670 - accuracy: 0.9440 - val_loss: 2.4746 - val_accuracy: 0.4933
# Epoch 33/70
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1375 - accuracy: 0.9580 - val_loss: 2.3988 - val_accuracy: 0.5020
# Epoch 34/70
# 16/16 [==============================] - 1s 75ms/step - loss: 0.1073 - accuracy: 0.9740 - val_loss: 2.4565 - val_accuracy: 0.4953
# Epoch 35/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0744 - accuracy: 0.9760 - val_loss: 2.6816 - val_accuracy: 0.4853
# Epoch 36/70
# 16/16 [==============================] - 1s 77ms/step - loss: 0.1686 - accuracy: 0.9620 - val_loss: 2.9603 - val_accuracy: 0.4400
# Epoch 37/70
# 16/16 [==============================] - 2s 116ms/step - loss: 0.1427 - accuracy: 0.9560 - val_loss: 2.8651 - val_accuracy: 0.4767
# Epoch 38/70
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0823 - accuracy: 0.9800 - val_loss: 2.5594 - val_accuracy: 0.5080
# Epoch 39/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0527 - accuracy: 0.9900 - val_loss: 2.6806 - val_accuracy: 0.5080
# Epoch 40/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0409 - accuracy: 0.9940 - val_loss: 2.7090 - val_accuracy: 0.5120
# Epoch 41/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0304 - accuracy: 0.9940 - val_loss: 2.9813 - val_accuracy: 0.4920
# Epoch 42/70
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0303 - accuracy: 0.9940 - val_loss: 3.0548 - val_accuracy: 0.4753
# Epoch 43/70
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0438 - accuracy: 0.9860 - val_loss: 2.9081 - val_accuracy: 0.5127
# Epoch 44/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0473 - accuracy: 0.9880 - val_loss: 3.0635 - val_accuracy: 0.4820
# Epoch 45/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0601 - accuracy: 0.9840 - val_loss: 2.8387 - val_accuracy: 0.5067
# Epoch 46/70
# 16/16 [==============================] - 1s 86ms/step - loss: 0.0535 - accuracy: 0.9860 - val_loss: 2.7942 - val_accuracy: 0.5120
# Epoch 47/70
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0367 - accuracy: 0.9900 - val_loss: 2.8121 - val_accuracy: 0.5080
# Epoch 48/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0292 - accuracy: 0.9960 - val_loss: 3.0047 - val_accuracy: 0.5160
# Epoch 49/70
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0228 - accuracy: 0.9940 - val_loss: 3.0057 - val_accuracy: 0.5213
# Epoch 50/70
# 16/16 [==============================] - 1s 73ms/step - loss: 0.0355 - accuracy: 0.9920 - val_loss: 3.5102 - val_accuracy: 0.4667
# Epoch 51/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0593 - accuracy: 0.9820 - val_loss: 3.0235 - val_accuracy: 0.5027
# Epoch 52/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0468 - accuracy: 0.9860 - val_loss: 2.8815 - val_accuracy: 0.5113
# Epoch 53/70
# 16/16 [==============================] - 1s 81ms/step - loss: 0.0288 - accuracy: 0.9920 - val_loss: 3.8837 - val_accuracy: 0.4673
# Epoch 54/70
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0644 - accuracy: 0.9760 - val_loss: 3.1440 - val_accuracy: 0.4927
# Epoch 55/70
# 16/16 [==============================] - 2s 120ms/step - loss: 0.0997 - accuracy: 0.9660 - val_loss: 3.1993 - val_accuracy: 0.4980
# Epoch 56/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0626 - accuracy: 0.9740 - val_loss: 2.6296 - val_accuracy: 0.5053
# Epoch 57/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0321 - accuracy: 0.9920 - val_loss: 2.9677 - val_accuracy: 0.5200
# Epoch 58/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0348 - accuracy: 0.9880 - val_loss: 3.4439 - val_accuracy: 0.4653
# Epoch 59/70
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0567 - accuracy: 0.9800 - val_loss: 2.9995 - val_accuracy: 0.4980
# Epoch 60/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0634 - accuracy: 0.9800 - val_loss: 3.5338 - val_accuracy: 0.4653
# Epoch 61/70
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0240 - accuracy: 0.9960 - val_loss: 3.1330 - val_accuracy: 0.4793
# Epoch 62/70
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0162 - accuracy: 0.9960 - val_loss: 3.2608 - val_accuracy: 0.4847
# Epoch 63/70
# 16/16 [==============================] - 1s 75ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 3.1888 - val_accuracy: 0.4987
# Epoch 64/70
# 16/16 [==============================] - 1s 77ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 3.0874 - val_accuracy: 0.5213
# Epoch 65/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0331 - accuracy: 0.9900 - val_loss: 3.4375 - val_accuracy: 0.4687
# Epoch 66/70
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0247 - accuracy: 0.9940 - val_loss: 2.9832 - val_accuracy: 0.5113
# Epoch 67/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0181 - accuracy: 0.9960 - val_loss: 3.2983 - val_accuracy: 0.5127
# Epoch 68/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 3.1954 - val_accuracy: 0.5073
# Epoch 69/70
# 16/16 [==============================] - 1s 80ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 3.3639 - val_accuracy: 0.4893
# Epoch 70/70
# 16/16 [==============================] - 1s 88ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 3.3173 - val_accuracy: 0.5080

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot accuracy graph
ax1.plot(history.history['accuracy'], label='accuracy')
ax1.plot(history.history['val_accuracy'], label='val_accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim([0.05, 1])
ax1.legend(loc='lower right')

# Plot loss graph
ax2.plot(history.history['loss'], label='loss')
ax2.plot(history.history['val_loss'], label='val_loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim([0.1, 10])
ax2.legend(loc='lower right')

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # TUNNING HYPERPARAMETERS

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), strides=(1,1), padding='same', activation='relu', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2,2), padding='same'))
model.add(layers.Conv2D(64, (3, 3), strides=(2,2), padding='same', activation='relu'))
model.add(layers.MaxPooling2D((4,4), padding='same'))
model.add(layers.Conv2D(128, (3, 3), strides=(2,2), padding='same', activation='relu'))
model.add(layers.MaxPooling2D((4, 4),padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(500, activation='relu'))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(250, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 500)               64500
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense_1 (Dense)             (None, 250)               125250
#
#  dropout_1 (Dropout)         (None, 250)               0
#
#  dense_2 (Dense)             (None, 10)                2510
#
# =================================================================
# Total params: 285,508
# Trainable params: 285,508
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

history = model.fit(np.array(imagesTraining), np.array(labelsTraining), epochs=70, validation_data=(np.array(imagesTesting), np.array(labelsTesting)))
# Out:
# Epoch 1/70
# 16/16 [==============================] - 8s 377ms/step - loss: 0.1253 - accuracy: 0.9580 - val_loss: 3.3612 - val_accuracy: 0.4820
# Epoch 2/70
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0416 - accuracy: 0.9820 - val_loss: 3.6860 - val_accuracy: 0.4587
# Epoch 3/70
# 16/16 [==============================] - 1s 78ms/step - loss: 0.0283 - accuracy: 0.9900 - val_loss: 3.3810 - val_accuracy: 0.4933
# Epoch 4/70
# 16/16 [==============================] - 1s 76ms/step - loss: 0.0095 - accuracy: 0.9980 - val_loss: 3.4281 - val_accuracy: 0.4953
# Epoch 5/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 3.4855 - val_accuracy: 0.5027
# Epoch 6/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.5370 - val_accuracy: 0.5047
# Epoch 7/70
# 16/16 [==============================] - 1s 80ms/step - loss: 0.0036 - accuracy: 0.9980 - val_loss: 3.7122 - val_accuracy: 0.5107
# Epoch 8/70
# 16/16 [==============================] - 2s 122ms/step - loss: 0.0100 - accuracy: 0.9940 - val_loss: 3.8973 - val_accuracy: 0.4927
# Epoch 9/70
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0176 - accuracy: 0.9900 - val_loss: 3.9928 - val_accuracy: 0.4893
# Epoch 10/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0486 - accuracy: 0.9740 - val_loss: 4.3129 - val_accuracy: 0.4680
# Epoch 11/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.1088 - accuracy: 0.9720 - val_loss: 3.9810 - val_accuracy: 0.4580
# Epoch 12/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0875 - accuracy: 0.9720 - val_loss: 3.6017 - val_accuracy: 0.4733
# Epoch 13/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0679 - accuracy: 0.9780 - val_loss: 3.7736 - val_accuracy: 0.4453
# Epoch 14/70
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0296 - accuracy: 0.9940 - val_loss: 3.6030 - val_accuracy: 0.5013
# Epoch 15/70
# 16/16 [==============================] - 1s 86ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 3.7610 - val_accuracy: 0.4900
# Epoch 16/70
# 16/16 [==============================] - 1s 79ms/step - loss: 0.0187 - accuracy: 0.9960 - val_loss: 3.5580 - val_accuracy: 0.5020
# Epoch 17/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 3.7180 - val_accuracy: 0.4927
# Epoch 18/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.8543 - val_accuracy: 0.4887
# Epoch 19/70
# 16/16 [==============================] - 1s 79ms/step - loss: 0.0115 - accuracy: 0.9940 - val_loss: 3.7880 - val_accuracy: 0.4840
# Epoch 20/70
# 16/16 [==============================] - 1s 77ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 4.1119 - val_accuracy: 0.4880
# Epoch 21/70
# 16/16 [==============================] - 1s 77ms/step - loss: 0.0149 - accuracy: 0.9940 - val_loss: 4.2203 - val_accuracy: 0.4653
# Epoch 22/70
# 16/16 [==============================] - 1s 80ms/step - loss: 0.0329 - accuracy: 0.9920 - val_loss: 3.9398 - val_accuracy: 0.4760
# Epoch 23/70
# 16/16 [==============================] - 1s 79ms/step - loss: 0.0517 - accuracy: 0.9740 - val_loss: 4.5346 - val_accuracy: 0.4393
# Epoch 24/70
# 16/16 [==============================] - 2s 122ms/step - loss: 0.1148 - accuracy: 0.9620 - val_loss: 4.0132 - val_accuracy: 0.4747
# Epoch 25/70
# 16/16 [==============================] - 1s 80ms/step - loss: 0.0352 - accuracy: 0.9900 - val_loss: 3.6058 - val_accuracy: 0.4900
# Epoch 26/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 3.8648 - val_accuracy: 0.4773
# Epoch 27/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0213 - accuracy: 0.9940 - val_loss: 3.6241 - val_accuracy: 0.5000
# Epoch 28/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0179 - accuracy: 0.9940 - val_loss: 3.9367 - val_accuracy: 0.4820
# Epoch 29/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0709 - accuracy: 0.9700 - val_loss: 4.3645 - val_accuracy: 0.4453
# Epoch 30/70
# 16/16 [==============================] - 1s 78ms/step - loss: 0.0768 - accuracy: 0.9760 - val_loss: 4.5581 - val_accuracy: 0.4060
# Epoch 31/70
# 16/16 [==============================] - 1s 81ms/step - loss: 0.1155 - accuracy: 0.9580 - val_loss: 4.2946 - val_accuracy: 0.4480
# Epoch 32/70
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0512 - accuracy: 0.9860 - val_loss: 3.8136 - val_accuracy: 0.4947
# Epoch 33/70
# 16/16 [==============================] - 2s 121ms/step - loss: 0.0471 - accuracy: 0.9880 - val_loss: 3.8358 - val_accuracy: 0.4573
# Epoch 34/70
# 16/16 [==============================] - 2s 119ms/step - loss: 0.0313 - accuracy: 0.9940 - val_loss: 3.8178 - val_accuracy: 0.4840
# Epoch 35/70
# 16/16 [==============================] - 1s 78ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 3.7693 - val_accuracy: 0.4880
# Epoch 36/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 3.7336 - val_accuracy: 0.4907
# Epoch 37/70
# 16/16 [==============================] - 1s 77ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 3.6777 - val_accuracy: 0.5027
# Epoch 38/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 4.0004 - val_accuracy: 0.4953
# Epoch 39/70
# 16/16 [==============================] - 1s 82ms/step - loss: 0.0049 - accuracy: 0.9980 - val_loss: 3.6946 - val_accuracy: 0.4987
# Epoch 40/70
# 16/16 [==============================] - 1s 94ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.7815 - val_accuracy: 0.4893
# Epoch 41/70
# 16/16 [==============================] - 2s 123ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.8119 - val_accuracy: 0.4887
# Epoch 42/70
# 16/16 [==============================] - 1s 77ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 3.8693 - val_accuracy: 0.4947
# Epoch 43/70
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.8267 - val_accuracy: 0.4953
# Epoch 44/70
# 16/16 [==============================] - 1s 78ms/step - loss: 4.5280e-04 - accuracy: 1.0000 - val_loss: 3.8917 - val_accuracy: 0.4980
# Epoch 45/70
# 16/16 [==============================] - 2s 118ms/step - loss: 5.7189e-04 - accuracy: 1.0000 - val_loss: 3.9006 - val_accuracy: 0.5000
# Epoch 46/70
# 16/16 [==============================] - 2s 118ms/step - loss: 2.9986e-04 - accuracy: 1.0000 - val_loss: 3.9222 - val_accuracy: 0.4987
# Epoch 47/70
# 16/16 [==============================] - 2s 118ms/step - loss: 2.7274e-04 - accuracy: 1.0000 - val_loss: 3.9697 - val_accuracy: 0.5013
# Epoch 48/70
# 16/16 [==============================] - 2s 123ms/step - loss: 6.3212e-04 - accuracy: 1.0000 - val_loss: 3.9873 - val_accuracy: 0.5040
# Epoch 49/70
# 16/16 [==============================] - 2s 118ms/step - loss: 2.1968e-04 - accuracy: 1.0000 - val_loss: 4.0987 - val_accuracy: 0.5067
# Epoch 50/70
# 16/16 [==============================] - 2s 118ms/step - loss: 2.4213e-04 - accuracy: 1.0000 - val_loss: 4.1304 - val_accuracy: 0.5080
# Epoch 51/70
# 16/16 [==============================] - 2s 118ms/step - loss: 3.9287e-04 - accuracy: 1.0000 - val_loss: 4.1115 - val_accuracy: 0.5087
# Epoch 52/70
# 16/16 [==============================] - 1s 78ms/step - loss: 3.8949e-04 - accuracy: 1.0000 - val_loss: 4.1073 - val_accuracy: 0.5073
# Epoch 53/70
# 16/16 [==============================] - 1s 77ms/step - loss: 2.8803e-04 - accuracy: 1.0000 - val_loss: 4.1271 - val_accuracy: 0.5073
# Epoch 54/70
# 16/16 [==============================] - 2s 118ms/step - loss: 1.6770e-04 - accuracy: 1.0000 - val_loss: 4.1509 - val_accuracy: 0.5107
# Epoch 55/70
# 16/16 [==============================] - 2s 125ms/step - loss: 1.1480e-04 - accuracy: 1.0000 - val_loss: 4.1847 - val_accuracy: 0.5113
# Epoch 56/70
# 16/16 [==============================] - 1s 83ms/step - loss: 7.6849e-05 - accuracy: 1.0000 - val_loss: 4.2145 - val_accuracy: 0.5107
# Epoch 57/70
# 16/16 [==============================] - 2s 118ms/step - loss: 4.2209e-04 - accuracy: 1.0000 - val_loss: 4.2648 - val_accuracy: 0.5100
# Epoch 58/70
# 16/16 [==============================] - 1s 78ms/step - loss: 3.2757e-04 - accuracy: 1.0000 - val_loss: 4.2838 - val_accuracy: 0.5060
# Epoch 59/70
# 16/16 [==============================] - 2s 118ms/step - loss: 1.5900e-04 - accuracy: 1.0000 - val_loss: 4.2857 - val_accuracy: 0.5087
# Epoch 60/70
# 16/16 [==============================] - 1s 81ms/step - loss: 2.2537e-04 - accuracy: 1.0000 - val_loss: 4.2710 - val_accuracy: 0.5120
# Epoch 61/70
# 16/16 [==============================] - 2s 119ms/step - loss: 1.2487e-04 - accuracy: 1.0000 - val_loss: 4.2891 - val_accuracy: 0.5107
# Epoch 62/70
# 16/16 [==============================] - 2s 119ms/step - loss: 2.4013e-04 - accuracy: 1.0000 - val_loss: 4.2990 - val_accuracy: 0.5120
# Epoch 63/70
# 16/16 [==============================] - 2s 125ms/step - loss: 2.8116e-04 - accuracy: 1.0000 - val_loss: 4.2925 - val_accuracy: 0.5087
# Epoch 64/70
# 16/16 [==============================] - 2s 121ms/step - loss: 9.2957e-05 - accuracy: 1.0000 - val_loss: 4.2905 - val_accuracy: 0.5040
# Epoch 65/70
# 16/16 [==============================] - 2s 119ms/step - loss: 9.2060e-05 - accuracy: 1.0000 - val_loss: 4.3098 - val_accuracy: 0.5040
# Epoch 66/70
# 16/16 [==============================] - 1s 79ms/step - loss: 3.0186e-04 - accuracy: 1.0000 - val_loss: 4.3571 - val_accuracy: 0.5047
# Epoch 67/70
# 16/16 [==============================] - 2s 119ms/step - loss: 1.3333e-04 - accuracy: 1.0000 - val_loss: 4.4234 - val_accuracy: 0.5067
# Epoch 68/70
# 16/16 [==============================] - 1s 76ms/step - loss: 1.7818e-04 - accuracy: 1.0000 - val_loss: 4.4464 - val_accuracy: 0.5000
# Epoch 69/70
# 16/16 [==============================] - 1s 78ms/step - loss: 2.9960e-04 - accuracy: 1.0000 - val_loss: 4.4974 - val_accuracy: 0.4987
# Epoch 70/70
# 16/16 [==============================] - 1s 79ms/step - loss: 1.2867e-04 - accuracy: 1.0000 - val_loss: 4.5134 - val_accuracy: 0.5020

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot accuracy graph
ax1.plot(history.history['accuracy'], label='accuracy')
ax1.plot(history.history['val_accuracy'], label='val_accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim([0.05, 2])
ax1.legend(loc='lower right')

# Plot loss graph
ax2.plot(history.history['loss'], label='loss')
ax2.plot(history.history['val_loss'], label='val_loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim([0.01, 8])
ax2.legend(loc='lower right')

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # MODEL SAVE

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/cnn_modelo_trab.h5')
